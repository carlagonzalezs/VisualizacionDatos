# %%
## Clase 1 - Introduccion a Python

# %%
print('hola')

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.35900235, 0.57442935, 0.86362753, 0.8194923 , 0.13226652,
#        0.38990809, 0.64955817, 0.05732134, 0.68676153, 0.44718674,
#        0.57766529, 0.20062235, 0.25315308, 0.60586948, 0.36807306,
#        0.0706132 , 0.51136449, 0.62753016, 0.9698386 , 0.2185453 ,
#        0.67933333, 0.66334501, 0.860172  , 0.59347522, 0.3550736 ,
#        0.50025796, 0.91515065, 0.48871068, 0.06857452, 0.4868814 ,
#        0.08293475, 0.63481157, 0.30142418, 0.60540518, 0.28149617,
#        0.76696507, 0.31105464, 0.20939916, 0.90545   , 0.15776994,
#        0.66165802, 0.39118388, 0.54051583, 0.28840117, 0.85502269,
#        0.29567232, 0.02947731, 0.83290964, 0.37243891, 0.71489987])

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    02_02_basic_math.ipynb
# 00_00_primer_pasos.ipynb              ClaseIntro.ipynb
# 01_01_data_types.ipynb                datasets/
# 01_02_read_iloc_unique_groupby.ipynb  README.md
# 02_00_data_wrangling.ipynb            requirements.txt
# 02_01_null_display.ipynb

# %%
#tipos de datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[4]
# Out:
# 5

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
lenght = len(numbers)
lenght
# Out:
# 5

# %%
promedio = sum_numbers/lenght
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool
